# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadmotiurrahman/mohammadmotiurrahman.github.io/blob/main/cse203/code/CSE203SoftwareRequirement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Microsoft Visual Studio 2019 is strongly preferred for this course.
#
#
# This detailed [note](https://docs.google.com/document/d/1S5Nc0v4qk72sMvKO03WrSVhvJLR3XP7DYnbxkjkleNI/edit?usp=sharing) shows how to install and use Microsoft Visual Studio in your PC.
#
# Thanks.
